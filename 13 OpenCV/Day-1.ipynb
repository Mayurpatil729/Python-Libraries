# %%
# To Show Image
import cv2
image = cv2.imread(filename="demo.jpg")
cv2.imshow("My Picture", image)
cv2.waitKey(1000)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # To Show Image
# ----> 2 import cv2
#       3 image = cv2.imread(filename="demo.jpg")
#       4 cv2.imshow("My Picture", image)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Image Shape : RGB
image = cv2.imread(filename="demo.jpg")
print(image.shape)
cv2.imshow("My Picture", image)
cv2.waitKey(1000)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Image Shape : RGB
# ----> 2 image = cv2.imread(filename="demo.jpg")
#       3 print(image.shape)
#       4 cv2.imshow("My Picture", image)
#
# NameError: name 'cv2' is not defined

# %%
import cv2

print(cv2.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import cv2
#       3 print(cv2.__version__)
#
# ModuleNotFoundError: No module named 'cv2'
